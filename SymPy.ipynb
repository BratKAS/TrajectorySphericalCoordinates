# %%
from sympy import *

init_printing(use_unicode=True)

x, t, z, nu = symbols('x t z nu')

y = sin(x)*exp(x)

diff(y, x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
integrate(exp(x)*sin(x) + exp(x)*cos(x), x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
integrate(sin(x**2), (x, -oo, oo))
# Out:
# √2⋅√π
# ─────
#   2

# %%
limit(sin(x)/x, x, 0)
# Out:
# 0

# %%
solve(x**2 - 2, x)
# Out:
# [-√2, √2]

# %%
y = Function('y')
dsolve(Eq(y(t).diff(t, t) - y(t), exp(t)), y(t))
# Out:
#            -t   ⎛     t⎞  t
# y(t) = C₂⋅ℯ   + ⎜C₁ + ─⎟⋅ℯ
#                 ⎝     2⎠

# %%
Matrix([[1, 2], [2, 2]]).eigenvals()
# Out:
# ⎧3   √17     3   √17   ⎫
# ⎨─ - ───: 1, ─ + ───: 1⎬
# ⎩2    2      2    2    ⎭

# %%
besselj(nu, z).rewrite(jn)
# Out:
# √2⋅√z⋅jn(ν - 1/2, z)
# ────────────────────
#          √π

# %%
y = symbols('y')
expr = x*y + x - 3 + 2*x**2 - z*x**2 + x**3

collected_expr = collect(expr, x)
collected_expr
# Out:
#  3    2
# x  + x ⋅(2 - z) + x⋅(y + 1) - 3

# %%
collected_expr.coeff(x, 2)
# Out:
# 2 - z

# %%
expr = (x**2 + 2*x + 1)/(x**2 + x)
expr
# Out:
#  2
# x  + 2⋅x + 1
# ────────────
#     2
#    x  + x

# %%
cancel(expr)
# Out:
# x + 1
# ─────
#   x

# %%
expr = (4*x**3 + 21*x**2 + 10*x + 12)/(x**4 + 5*x**3 + 5*x**2 + 4*x)
expr
# Out:
#    3       2
# 4⋅x  + 21⋅x  + 10⋅x + 12
# ────────────────────────
#   4      3      2
#  x  + 5⋅x  + 5⋅x  + 4⋅x

# %%
apart(expr)
# Out:
#  2⋅x - 1       1     3
# ────────── - ───── + ─
#  2           x + 4   x
# x  + x + 1

# %%
expr = sin(x)**4 - 2*cos(x)**2*sin(x)**2 + cos(x)**4
expr
# Out:
#    4           2       2         4
# sin (x) - 2⋅sin (x)⋅cos (x) + cos (x)

# %%
trigsimp(expr)
# Out:
# cos(4⋅x)   1
# ──────── + ─
#    2       2

# %%
expand_trig(sin(x + y))
# Out:
# sin(x)⋅cos(y) + sin(y)⋅cos(x)

# %%
expand_trig(tan(2*x))
# Out:
#  2⋅tan(x)
# ───────────
#        2
# 1 - tan (x)

# %%
x, y = symbols('x y', positive=True)
a, b = symbols('a b', real=True)
z, t, c = symbols('z t c')

powsimp(x**a*x**b)
# Out:
#  a + b
# x

# %%
expand_power_exp(x**(a + b))
# Out:
#  a  b
# x ⋅x

# %%
from sympy import Integral, Symbol, sqrt
x = Symbol('x')
integral = Integral(sqrt(2)*x, (x, 0, 1))
integral
# Out:
# 1
# ⌠
# ⎮ √2⋅x dx
# ⌡
# 0

# %%
integral.evalf()
# Out:
# 0.707106781186548

# %%
expr = exp(sin(x))
expr
# Out:
#  sin(x)
# ℯ

# %%
expr.series(x, 0, 4)
# Out:
#          2
#         x     ⎛ 4⎞
# 1 + x + ── + O⎝x ⎠
#         2

# %%
solveset(x - x, x, domain=S.Reals)
# Out:
# ℝ

# %%
solveset(sin(x) - 1, x, domain=S.Reals)
# Out:
# ⎧        π │      ⎫
# ⎨2⋅n⋅π + ─ │ n ∊ ℤ⎬
# ⎩        2 │      ⎭

# %%
solveset(exp(x), x)
# Out:
# ∅

# %%
Matrix(([1, 1, 1, 1], [1, 1, 2, 3]))
# Out:
# ⎡1  1  1  1⎤
# ⎢          ⎥
# ⎣1  1  2  3⎦

# %%
# %matplotlib inline

from sympy import symbols
from sympy.plotting import plot3d
x, y = symbols('x y')
p = plot3d(x*y, (x, -5, 5), (y, -5, 5))

# %%
t = symbols('t')
ab = [(1, 1), (1, 2), (2, 3), (2, 5), (3, 5), (3, 7), (4, 5), (5, 8), (7, 8), (8, 9)]

for a, b in ab:
    plot_parametric(sin(a*t), sin(b*t), (t, 0, 2*pi), title=fr'$a={a}, \ b={b}$', xlabel=r'$\sin(at)$', ylabel=r'$\sin(bt)$')
